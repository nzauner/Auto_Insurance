# %%
# %matplotlib inline

# %%
import pandas as pd
from utility.functions import *

# %%
auto_data = pd.read_csv('data/auto_data.csv')

# %%
missingno.matrix(auto_data)

# %%
auto_ins_df.INCOME.describe()

# %%
auto_ins_df.INCOME.unique

# %%
auto_ins_df.isna().sum()

# %%
auto_ins_df.info()

# %%
auto_ins_df.INCOME.describe()

# %%
auto_col = auto_ins_df.columns.values.tolist()

# %%
from yellowbrick.features import Rank2D

# Load the credit dataset
#X, y = auto_ins_df

# Instantiate the visualizer with the covariance ranking algorithm
visualizer = Rank2D(algorithm='covariance', features=auto_col)

visualizer.fit           # Fit the data to the visualizer
visualizer.transform()        # Transform the data
visualizer.show()              # Finalize and render the figure

# %%
auto_col
